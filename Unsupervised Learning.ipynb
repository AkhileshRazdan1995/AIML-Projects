# %%
#importing required packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
from sklearn.metrics import confusion_matrix
from sklearn.cluster import KMeans 
# importing the StandardScaler Module
from sklearn.preprocessing import StandardScaler
from scipy.spatial.distance import cdist
from sklearn.model_selection import train_test_split
from sklearn.metrics import silhouette_samples, silhouette_score
import matplotlib.ticker as mtick # For specifying the axes tick format 
from sklearn import svm
from sklearn.metrics import accuracy_score
from sklearn.metrics import recall_score
from sklearn.decomposition import PCA

# %%
#Read ‘vehicle.csv’ and save as DataFrame
dataset=pd.read_csv("vehicle.csv")
dataset.head(5)
# Out:
#    compactness  circularity  distance_circularity  radius_ratio  \
# 0           95         48.0                  83.0         178.0
# 1           91         41.0                  84.0         141.0
# 2          104         50.0                 106.0         209.0
# 3           93         41.0                  82.0         159.0
# 4           85         44.0                  70.0         205.0
#
#    pr.axis_aspect_ratio  max.length_aspect_ratio  scatter_ratio  \
# 0                  72.0                       10          162.0
# 1                  57.0                        9          149.0
# 2                  66.0                       10          207.0
# 3                  63.0                        9          144.0
# 4                 103.0                       52          149.0
#
#    elongatedness  pr.axis_rectangularity  max.length_rectangularity  \
# 0           42.0                    20.0                        159
# 1           45.0                    19.0                        143
# 2           32.0                    23.0                        158
# 3           46.0                    19.0                        143
# 4           45.0                    19.0                        144
#
#    scaled_variance  scaled_variance.1  scaled_radius_of_gyration  \
# 0            176.0              379.0                      184.0
# 1            170.0              330.0                      158.0
# 2            223.0              635.0                      220.0
# 3            160.0              309.0                      127.0
# 4            241.0              325.0                      188.0
#
#    scaled_radius_of_gyration.1  skewness_about  skewness_about.1  \
# 0                         70.0             6.0              16.0
# 1                         72.0             9.0              14.0
# 2                         73.0            14.0               9.0
# 3                         63.0             6.0              10.0
# 4                        127.0             9.0              11.0
#
#    skewness_about.2  hollows_ratio class
# 0             187.0            197   van
# 1             189.0            199   van
# 2             188.0            196   car
# 3             199.0            207   van
# 4             180.0            183   bus

# %%
#5 point summary
dataset.describe().T
# Out:
#                              count        mean         std    min     25%  \
# compactness                  846.0   93.678487    8.234474   73.0   87.00
# circularity                  841.0   44.828775    6.152172   33.0   40.00
# distance_circularity         842.0   82.110451   15.778292   40.0   70.00
# radius_ratio                 840.0  168.888095   33.520198  104.0  141.00
# pr.axis_aspect_ratio         844.0   61.678910    7.891463   47.0   57.00
# max.length_aspect_ratio      846.0    8.567376    4.601217    2.0    7.00
# scatter_ratio                845.0  168.901775   33.214848  112.0  147.00
# elongatedness                845.0   40.933728    7.816186   26.0   33.00
# pr.axis_rectangularity       843.0   20.582444    2.592933   17.0   19.00
# max.length_rectangularity    846.0  147.998818   14.515652  118.0  137.00
# scaled_variance              843.0  188.631079   31.411004  130.0  167.00
# scaled_variance.1            844.0  439.494076  176.666903  184.0  318.00
# scaled_radius_of_gyration    844.0  174.709716   32.584808  109.0  149.00
# scaled_radius_of_gyration.1  842.0   72.447743    7.486190   59.0   67.00
# skewness_about               840.0    6.364286    4.920649    0.0    2.00
# skewness_about.1             845.0   12.602367    8.936081    0.0    5.00
# skewness_about.2             845.0  188.919527    6.155809  176.0  184.00
# hollows_ratio                846.0  195.632388    7.438797  181.0  190.25
#
#                                50%    75%     max
# compactness                   93.0  100.0   119.0
# circularity                   44.0   49.0    59.0
# distance_circularity          80.0   98.0   112.0
# radius_ratio                 167.0  195.0   333.0
# pr.axis_aspect_ratio          61.0   65.0   138.0
# max.length_aspect_ratio        8.0   10.0    55.0
# scatter_ratio                157.0  198.0   265.0
# elongatedness                 43.0   46.0    61.0
# pr.axis_rectangularity        20.0   23.0    29.0
# max.length_rectangularity    146.0  159.0   188.0
# scaled_variance              179.0  217.0   320.0
# scaled_variance.1            363.5  587.0  1018.0
# scaled_radius_of_gyration    173.5  198.0   268.0
# scaled_radius_of_gyration.1   71.5   75.0   135.0
# skewness_about                 6.0    9.0    22.0
# skewness_about.1              11.0   19.0    41.0
# skewness_about.2             188.0  193.0   206.0
# hollows_ratio                197.0  201.0   211.0

# %%
#display dataset
dataset.head()
# Out:
#    compactness  circularity  distance_circularity  radius_ratio  \
# 0           95         48.0                  83.0         178.0
# 1           91         41.0                  84.0         141.0
# 2          104         50.0                 106.0         209.0
# 3           93         41.0                  82.0         159.0
# 4           85         44.0                  70.0         205.0
#
#    pr.axis_aspect_ratio  max.length_aspect_ratio  scatter_ratio  \
# 0                  72.0                       10          162.0
# 1                  57.0                        9          149.0
# 2                  66.0                       10          207.0
# 3                  63.0                        9          144.0
# 4                 103.0                       52          149.0
#
#    elongatedness  pr.axis_rectangularity  max.length_rectangularity  \
# 0           42.0                    20.0                        159
# 1           45.0                    19.0                        143
# 2           32.0                    23.0                        158
# 3           46.0                    19.0                        143
# 4           45.0                    19.0                        144
#
#    scaled_variance  scaled_variance.1  scaled_radius_of_gyration  \
# 0            176.0              379.0                      184.0
# 1            170.0              330.0                      158.0
# 2            223.0              635.0                      220.0
# 3            160.0              309.0                      127.0
# 4            241.0              325.0                      188.0
#
#    scaled_radius_of_gyration.1  skewness_about  skewness_about.1  \
# 0                         70.0             6.0              16.0
# 1                         72.0             9.0              14.0
# 2                         73.0            14.0               9.0
# 3                         63.0             6.0              10.0
# 4                        127.0             9.0              11.0
#
#    skewness_about.2  hollows_ratio class
# 0             187.0            197   van
# 1             189.0            199   van
# 2             188.0            196   car
# 3             199.0            207   van
# 4             180.0            183   bus

# %%
dataset.isna().sum()
# Out:
# compactness                    0
# circularity                    5
# distance_circularity           4
# radius_ratio                   6
# pr.axis_aspect_ratio           2
# max.length_aspect_ratio        0
# scatter_ratio                  1
# elongatedness                  1
# pr.axis_rectangularity         3
# max.length_rectangularity      0
# scaled_variance                3
# scaled_variance.1              2
# scaled_radius_of_gyration      2
# scaled_radius_of_gyration.1    4
# skewness_about                 6
# skewness_about.1               1
# skewness_about.2               1
# hollows_ratio                  0
# class                          0
# dtype: int64

# %%
#Check percentage of missing values and impute with correct approach
(((dataset.isna().sum())/846)*100)
# Out:
# compactness                    0.000000
# circularity                    0.591017
# distance_circularity           0.472813
# radius_ratio                   0.709220
# pr.axis_aspect_ratio           0.236407
# max.length_aspect_ratio        0.000000
# scatter_ratio                  0.118203
# elongatedness                  0.118203
# pr.axis_rectangularity         0.354610
# max.length_rectangularity      0.000000
# scaled_variance                0.354610
# scaled_variance.1              0.236407
# scaled_radius_of_gyration      0.236407
# scaled_radius_of_gyration.1    0.472813
# skewness_about                 0.709220
# skewness_about.1               0.118203
# skewness_about.2               0.118203
# hollows_ratio                  0.000000
# class                          0.000000
# dtype: float64

# %%
dataset=dataset.dropna()

# %%
#5 point summary
dataset.describe().T
# Out:
#                              count        mean         std    min    25%  \
# compactness                  813.0   93.656827    8.233751   73.0   87.0
# circularity                  813.0   44.803198    6.146659   33.0   40.0
# distance_circularity         813.0   82.043050   15.783070   40.0   70.0
# radius_ratio                 813.0  169.098401   33.615402  104.0  141.0
# pr.axis_aspect_ratio         813.0   61.774908    7.973000   47.0   57.0
# max.length_aspect_ratio      813.0    8.599016    4.677174    2.0    7.0
# scatter_ratio                813.0  168.563346   33.082186  112.0  146.0
# elongatedness                813.0   40.988930    7.803380   26.0   33.0
# pr.axis_rectangularity       813.0   20.558426    2.573184   17.0   19.0
# max.length_rectangularity    813.0  147.891759   14.504648  118.0  137.0
# scaled_variance              813.0  188.377614   31.165873  130.0  167.0
# scaled_variance.1            813.0  438.382534  175.270368  184.0  318.0
# scaled_radius_of_gyration    813.0  174.252153   32.332161  109.0  149.0
# scaled_radius_of_gyration.1  813.0   72.399754    7.475994   59.0   67.0
# skewness_about               813.0    6.351784    4.921476    0.0    2.0
# skewness_about.1             813.0   12.687577    8.926951    0.0    6.0
# skewness_about.2             813.0  188.979090    6.153681  176.0  184.0
# hollows_ratio                813.0  195.729397    7.398781  181.0  191.0
#
#                                50%    75%     max
# compactness                   93.0  100.0   119.0
# circularity                   44.0   49.0    59.0
# distance_circularity          79.0   98.0   112.0
# radius_ratio                 167.0  195.0   333.0
# pr.axis_aspect_ratio          61.0   65.0   138.0
# max.length_aspect_ratio        8.0   10.0    55.0
# scatter_ratio                157.0  198.0   265.0
# elongatedness                 43.0   46.0    61.0
# pr.axis_rectangularity        20.0   23.0    29.0
# max.length_rectangularity    146.0  159.0   188.0
# scaled_variance              179.0  217.0   320.0
# scaled_variance.1            364.0  586.0  1018.0
# scaled_radius_of_gyration    173.0  198.0   268.0
# scaled_radius_of_gyration.1   71.0   75.0   135.0
# skewness_about                 6.0    9.0    22.0
# skewness_about.1              11.0   19.0    41.0
# skewness_about.2             189.0  193.0   206.0
# hollows_ratio                197.0  201.0   211.0

# %%
dataset.isna().sum()
# Out:
# compactness                    0
# circularity                    0
# distance_circularity           0
# radius_ratio                   0
# pr.axis_aspect_ratio           0
# max.length_aspect_ratio        0
# scatter_ratio                  0
# elongatedness                  0
# pr.axis_rectangularity         0
# max.length_rectangularity      0
# scaled_variance                0
# scaled_variance.1              0
# scaled_radius_of_gyration      0
# scaled_radius_of_gyration.1    0
# skewness_about                 0
# skewness_about.1               0
# skewness_about.2               0
# hollows_ratio                  0
# class                          0
# dtype: int64

# %%
(((dataset.isna().sum())/813)*100)
# Out:
# compactness                    0.0
# circularity                    0.0
# distance_circularity           0.0
# radius_ratio                   0.0
# pr.axis_aspect_ratio           0.0
# max.length_aspect_ratio        0.0
# scatter_ratio                  0.0
# elongatedness                  0.0
# pr.axis_rectangularity         0.0
# max.length_rectangularity      0.0
# scaled_variance                0.0
# scaled_variance.1              0.0
# scaled_radius_of_gyration      0.0
# scaled_radius_of_gyration.1    0.0
# skewness_about                 0.0
# skewness_about.1               0.0
# skewness_about.2               0.0
# hollows_ratio                  0.0
# class                          0.0
# dtype: float64

# %%
#Visualize a Pie-chart and print percentage of values for variable ‘class
lab=dataset['class'].unique()
ax = (dataset['class'].value_counts()*100.0 /len(dataset))\
.plot.pie(autopct='%.1f%%', labels = lab,figsize =(5,5), fontsize = 12 )                                                                           
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.set_ylabel('class',fontsize = 12)
ax.set_title('% of class', fontsize = 12)
# Out:
# Text(0.5, 1.0, '% of class')

# %%
# the color intensity 
fig,ax = plt.subplots(figsize=(10, 10))
sns.heatmap(dataset.corr(), ax=ax, annot=True, linewidths=0.05, fmt= '.2f',cmap="magma") 
plt.show()

# %%
#Visualize a scatterplot for ‘wt’ and ‘disp’. Datapoints are distinguishable by ‘cyl’
sns.scatterplot(x="compactness",y="circularity",hue="distance_circularity",data=dataset)
plt.show()

# %%
#Visualize a scatterplot for ‘wt’ and ‘mpg’. Datapoints are distinguishable by ‘cyl’
sns.scatterplot(x="compactness",y="radius_ratio",hue="distance_circularity",data=dataset)
plt.show()

# %%
#Visualize a scatterplot for ‘wt’ and ‘mpg’. Datapoints are distinguishable by ‘cyl’
sns.scatterplot(x="compactness",y="scatter_ratio",hue="distance_circularity",data=dataset)
plt.show()

# %%
#Visualize a scatterplot for ‘wt’ and ‘mpg’. Datapoints are distinguishable by ‘cyl’
sns.scatterplot(x="elongatedness",y="compactness",hue="distance_circularity",data=dataset)
plt.show()

# %%
#Check for duplicate rows in the data and impute with correct approach
dataset.duplicated().sum()
# Out:
# 0

# %%
correlation = dataset.corr()
correlation
# Out:
#                              compactness  circularity  distance_circularity  \
# compactness                     1.000000     0.689885              0.789955
# circularity                     0.689885     1.000000              0.797704
# distance_circularity            0.789955     0.797704              1.000000
# radius_ratio                    0.688130     0.623950              0.771404
# pr.axis_aspect_ratio            0.090557     0.155023              0.163386
# max.length_aspect_ratio         0.150369     0.251619              0.265591
# scatter_ratio                   0.814026     0.858149              0.909023
# elongatedness                  -0.788051    -0.825108             -0.912713
# pr.axis_rectangularity          0.814227     0.856137              0.897261
# max.length_rectangularity       0.674902     0.965366              0.773459
# scaled_variance                 0.764386     0.806108              0.865683
# scaled_variance.1               0.820240     0.850932              0.891789
# scaled_radius_of_gyration       0.581405     0.935594              0.705689
# scaled_radius_of_gyration.1    -0.258437     0.049070             -0.238145
# skewness_about                  0.231648     0.141726              0.110280
# skewness_about.1                0.168384    -0.001975              0.277851
# skewness_about.2                0.296195    -0.113902              0.145258
# hollows_ratio                   0.372806     0.049331              0.343228
#
#                              radius_ratio  pr.axis_aspect_ratio  \
# compactness                      0.688130              0.090557
# circularity                      0.623950              0.155023
# distance_circularity             0.771404              0.163386
# radius_ratio                     1.000000              0.667375
# pr.axis_aspect_ratio             0.667375              1.000000
# max.length_aspect_ratio          0.452460              0.652093
# scatter_ratio                    0.743470              0.113696
# elongatedness                   -0.795761             -0.191193
# pr.axis_rectangularity           0.716210              0.086992
# max.length_rectangularity        0.570478              0.133553
# scaled_variance                  0.806788              0.290375
# scaled_variance.1                0.731773              0.100668
# scaled_radius_of_gyration        0.544636              0.135663
# scaled_radius_of_gyration.1     -0.175348              0.173060
# skewness_about                   0.044693             -0.059244
# skewness_about.1                 0.178079             -0.040769
# skewness_about.2                 0.375591              0.229702
# hollows_ratio                    0.470895              0.257566
#
#                              max.length_aspect_ratio  scatter_ratio  \
# compactness                                 0.150369       0.814026
# circularity                                 0.251619       0.858149
# distance_circularity                        0.265591       0.909023
# radius_ratio                                0.452460       0.743470
# pr.axis_aspect_ratio                        0.652093       0.113696
# max.length_aspect_ratio                     1.000000       0.171445
# scatter_ratio                               0.171445       1.000000
# elongatedness                              -0.183242      -0.973413
# pr.axis_rectangularity                      0.167514       0.991992
# max.length_rectangularity                   0.309180       0.808154
# scaled_variance                             0.331124       0.950067
# scaled_variance.1                           0.150069       0.996396
# scaled_radius_of_gyration                   0.197179       0.795748
# scaled_radius_of_gyration.1                 0.308329      -0.045632
# skewness_about                              0.016461       0.070118
# skewness_about.1                            0.041210       0.227375
# skewness_about.2                           -0.030543       0.009967
# hollows_ratio                               0.139283       0.138424
#
#                              elongatedness  pr.axis_rectangularity  \
# compactness                      -0.788051                0.814227
# circularity                      -0.825108                0.856137
# distance_circularity             -0.912713                0.897261
# radius_ratio                     -0.795761                0.716210
# pr.axis_aspect_ratio             -0.191193                0.086992
# max.length_aspect_ratio          -0.183242                0.167514
# scatter_ratio                    -0.973413                0.991992
# elongatedness                     1.000000               -0.950345
# pr.axis_rectangularity           -0.950345                1.000000
# max.length_rectangularity        -0.771099                0.811979
# scaled_variance                  -0.937846                0.935653
# scaled_variance.1                -0.956858                0.992119
# scaled_radius_of_gyration        -0.761563                0.792895
# scaled_radius_of_gyration.1       0.119750               -0.033769
# skewness_about                   -0.046621                0.078701
# skewness_about.1                 -0.201325                0.231171
# skewness_about.2                 -0.117568               -0.017383
# hollows_ratio                    -0.233408                0.117202
#
#                              max.length_rectangularity  scaled_variance  \
# compactness                                   0.674902         0.764386
# circularity                                   0.965366         0.806108
# distance_circularity                          0.773459         0.865683
# radius_ratio                                  0.570478         0.806788
# pr.axis_aspect_ratio                          0.133553         0.290375
# max.length_aspect_ratio                       0.309180         0.331124
# scatter_ratio                                 0.808154         0.950067
# elongatedness                                -0.771099        -0.937846
# pr.axis_rectangularity                        0.811979         0.935653
# max.length_rectangularity                     1.000000         0.744760
# scaled_variance                               0.744760         1.000000
# scaled_variance.1                             0.796230         0.947617
# scaled_radius_of_gyration                     0.865240         0.776051
# scaled_radius_of_gyration.1                   0.031098         0.099371
# skewness_about                                0.130356         0.034228
# skewness_about.1                              0.013045         0.208966
# skewness_about.2                             -0.108019         0.017828
# hollows_ratio                                 0.086792         0.104989
#
#                              scaled_variance.1  scaled_radius_of_gyration  \
# compactness                           0.820240                   0.581405
# circularity                           0.850932                   0.935594
# distance_circularity                  0.891789                   0.705689
# radius_ratio                          0.731773                   0.544636
# pr.axis_aspect_ratio                  0.100668                   0.135663
# max.length_aspect_ratio               0.150069                   0.197179
# scatter_ratio                         0.996396                   0.795748
# elongatedness                        -0.956858                  -0.761563
# pr.axis_rectangularity                0.992119                   0.792895
# max.length_rectangularity             0.796230                   0.865240
# scaled_variance                       0.947617                   0.776051
# scaled_variance.1                     1.000000                   0.791997
# scaled_radius_of_gyration             0.791997                   1.000000
# scaled_radius_of_gyration.1          -0.037903                   0.177284
# skewness_about                        0.072393                   0.162397
# skewness_about.1                      0.220054                  -0.041153
# skewness_about.2                      0.011782                  -0.224495
# hollows_ratio                         0.125118                  -0.102167
#
#                              scaled_radius_of_gyration.1  skewness_about  \
# compactness                                    -0.258437        0.231648
# circularity                                     0.049070        0.141726
# distance_circularity                           -0.238145        0.110280
# radius_ratio                                   -0.175348        0.044693
# pr.axis_aspect_ratio                            0.173060       -0.059244
# max.length_aspect_ratio                         0.308329        0.016461
# scatter_ratio                                  -0.045632        0.070118
# elongatedness                                   0.119750       -0.046621
# pr.axis_rectangularity                         -0.033769        0.078701
# max.length_rectangularity                       0.031098        0.130356
# scaled_variance                                 0.099371        0.034228
# scaled_variance.1                              -0.037903        0.072393
# scaled_radius_of_gyration                       0.177284        0.162397
# scaled_radius_of_gyration.1                     1.000000       -0.088109
# skewness_about                                 -0.088109        1.000000
# skewness_about.1                               -0.120600       -0.022611
# skewness_about.2                               -0.748668        0.111135
# hollows_ratio                                  -0.798810        0.098128
#
#                              skewness_about.1  skewness_about.2  hollows_ratio
# compactness                          0.168384          0.296195       0.372806
# circularity                         -0.001975         -0.113902       0.049331
# distance_circularity                 0.277851          0.145258       0.343228
# radius_ratio                         0.178079          0.375591       0.470895
# pr.axis_aspect_ratio                -0.040769          0.229702       0.257566
# max.length_aspect_ratio              0.041210         -0.030543       0.139283
# scatter_ratio                        0.227375          0.009967       0.138424
# elongatedness                       -0.201325         -0.117568      -0.233408
# pr.axis_rectangularity               0.231171         -0.017383       0.117202
# max.length_rectangularity            0.013045         -0.108019       0.086792
# scaled_variance                      0.208966          0.017828       0.104989
# scaled_variance.1                    0.220054          0.011782       0.125118
# scaled_radius_of_gyration           -0.041153         -0.224495      -0.102167
# scaled_radius_of_gyration.1         -0.120600         -0.748668      -0.798810
# skewness_about                      -0.022611          0.111135       0.098128
# skewness_about.1                     1.000000          0.077942       0.201286
# skewness_about.2                     0.077942          1.000000       0.894057
# hollows_ratio                        0.201286          0.894057       1.000000

# %%
#encoding the catagorical values (target variable 0 is bus,1 is car and 2 is van  )
dataset['class']=dataset['class'].astype('category')
dataset['class']=dataset['class'].cat.codes
dataset.head()
# Out:
#    compactness  circularity  distance_circularity  radius_ratio  \
# 0           95         48.0                  83.0         178.0
# 1           91         41.0                  84.0         141.0
# 2          104         50.0                 106.0         209.0
# 3           93         41.0                  82.0         159.0
# 4           85         44.0                  70.0         205.0
#
#    pr.axis_aspect_ratio  max.length_aspect_ratio  scatter_ratio  \
# 0                  72.0                       10          162.0
# 1                  57.0                        9          149.0
# 2                  66.0                       10          207.0
# 3                  63.0                        9          144.0
# 4                 103.0                       52          149.0
#
#    elongatedness  pr.axis_rectangularity  max.length_rectangularity  \
# 0           42.0                    20.0                        159
# 1           45.0                    19.0                        143
# 2           32.0                    23.0                        158
# 3           46.0                    19.0                        143
# 4           45.0                    19.0                        144
#
#    scaled_variance  scaled_variance.1  scaled_radius_of_gyration  \
# 0            176.0              379.0                      184.0
# 1            170.0              330.0                      158.0
# 2            223.0              635.0                      220.0
# 3            160.0              309.0                      127.0
# 4            241.0              325.0                      188.0
#
#    scaled_radius_of_gyration.1  skewness_about  skewness_about.1  \
# 0                         70.0             6.0              16.0
# 1                         72.0             9.0              14.0
# 2                         73.0            14.0               9.0
# 3                         63.0             6.0              10.0
# 4                        127.0             9.0              11.0
#
#    skewness_about.2  hollows_ratio  class
# 0             187.0            197      2
# 1             189.0            199      2
# 2             188.0            196      1
# 3             199.0            207      2
# 4             180.0            183      0

# %%
#Split data into X and Y. [Train and Test optional] 
#Standardize the Data
X=dataset.drop('class', axis=1)
y=dataset['class']
X_Scaler = StandardScaler()
X_scaled = X_Scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.25, random_state=1)

# %%
#Train a base Classification model using SVM
clf = svm.SVC(gamma=0.010, C=95) 
clf.fit(X_train , y_train)
y_predict = clf.predict(X_test)
print("Accuracy : %1.4f " %(accuracy_score(y_test, y_predict)*100))
# Out:
# Accuracy : 98.5294

# %%
from sklearn.metrics import precision_recall_fscore_support, mean_absolute_error
print('\nMean Absolute Error of SVM:\n', mean_absolute_error(y_test, y_predict))
# Out:
# Mean Absolute Error of SVM:
#  0.0196078431372549

# %%
#Print Classification metrics for train data
df_cm= confusion_matrix(y_test, y_predict)
plt.figure(figsize = (7,5))
sns.heatmap(df_cm, annot=True)
# Out:
# <AxesSubplot:>

# %%
# Creating an object for the StandardScaler function to normailze the values
XScaler = StandardScaler()
scaled_df = XScaler.fit_transform(dataset.iloc[:,1:9])
scaled_df
# Out:
# array([[ 0.52040788,  0.06066872,  0.26497017, ..., -0.19851729,
#          0.12964799, -0.21715097],
#        [-0.61912319,  0.12406675, -0.83639333, ..., -0.59171992,
#          0.51433345, -0.60601383],
#        [ 0.84598818,  1.51882349,  1.18773418, ...,  1.16256874,
#         -1.15263688,  0.94943761],
#        ...,
#        [ 1.49714879,  1.20183332,  1.57469973, ...,  1.61626408,
#         -1.40909386,  1.72716333],
#        [-1.43307395, -0.25632145, -0.68756042, ..., -1.0151689 ,
#          1.15547589, -0.99487669],
#        [-1.43307395, -1.01709784, -1.37219178, ..., -1.46886425,
#          1.92484682, -1.38373955]])

# %%
#Apply K-Means clustering for 2 to 10 clusters.
#Plot a visual and find elbow point. 
#On the above visual, highlight which are the possible Elbow points. 
#Finding optimal no. of clusters
clusters=range(2,11)
meanDistortions=[]

#forming models for 2 to 10
for k in clusters:
    model=KMeans(n_clusters=k)
    model.fit(scaled_df)
    prediction=model.predict(scaled_df)
    meanDistortions.append(sum(np.min(cdist(scaled_df, model.cluster_centers_, 'euclidean'), axis=1)) / scaled_df.shape[0])

# ploting visual and find elbow point
plt.plot(clusters, meanDistortions, 'bx-')
plt.xlabel('k')
plt.grid()
plt.vlines(3, plt.ylim()[0], plt.ylim()[1], linestyles='dashed')
plt.ylabel('Average distortion')
plt.title('Selecting k with the Elbow Method')
# Out:
# Text(0.5, 1.0, 'Selecting k with the Elbow Method')

# %%
#Train a K-means clustering model once again on the optimal number of clusters.
# Let us first start with K = 3
final_model=KMeans(3)
final_model.fit(scaled_df)
prediction=final_model.predict(scaled_df)
dataset['cluster'] = final_model.fit_predict(scaled_df)
labels=final_model.labels_
test=silhouette_score(scaled_df,labels)
print("silhouette_score: %1.4f" %test)
#Append the prediction 
dataset["GROUP"] = prediction
print("Groups Assigned : \n")
dataset.head(3)
# Out:
# silhouette_score: 0.5364
# Groups Assigned :
#    compactness  circularity  distance_circularity  radius_ratio  \
# 0           95         48.0                  83.0         178.0
# 1           91         41.0                  84.0         141.0
# 2          104         50.0                 106.0         209.0
#
#    pr.axis_aspect_ratio  max.length_aspect_ratio  scatter_ratio  \
# 0                  72.0                       10          162.0
# 1                  57.0                        9          149.0
# 2                  66.0                       10          207.0
#
#    elongatedness  pr.axis_rectangularity  max.length_rectangularity  ...  \
# 0           42.0                    20.0                        159  ...
# 1           45.0                    19.0                        143  ...
# 2           32.0                    23.0                        158  ...
#
#    scaled_variance.1  scaled_radius_of_gyration  scaled_radius_of_gyration.1  \
# 0              379.0                      184.0                         70.0
# 1              330.0                      158.0                         72.0
# 2              635.0                      220.0                         73.0
#
#    skewness_about  skewness_about.1  skewness_about.2  hollows_ratio  class  \
# 0             6.0              16.0             187.0            197      2
# 1             9.0              14.0             189.0            199      2
# 2            14.0               9.0             188.0            196      1
#
#    cluster  GROUP
# 0        1      1
# 1        1      1
# 2        0      0
#
# [3 rows x 21 columns]

# %%
print(f"For n_clusters = {clusters}, the average silhouette score is: {test:.3f}")
# Out:
# For n_clusters = range(2, 11), the average silhouette score is: 0.536
